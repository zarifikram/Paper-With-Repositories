# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import os, sys
exec(open("init_notebook.py").read())
from DataTools import DataTools
from Extractor import Extractor
from DataCleaner import DataCleaner
from RepoTools import RepoTools
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 6
#       4 from tqdm import tqdm
#       5 import os, sys
# ----> 6 exec(open("init_notebook.py").read())
#       7 from DataTools import DataTools
#       8 from Extractor import Extractor
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'init_notebook.py'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 DataCleaner.getRepoInfoDfByCid(369)
#
# TypeError: getRepoInfoDfByCid() missing 1 required positional argument: 'companies'

# %%
pwc = pd.read_csv(os.path.join(os.pardir, 'data/papersWithCode.csv'))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 pwc[len(pwc['repo_url'] < 5)]
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/core/arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File ~/opt/anaconda3/envs/paper/lib/python3.8/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
mainDatasetPath = os.path.join(os.curdir, "../data/mainData.csv")
companyDf = pd.read_csv(mainDatasetPath)

# %%
len(companyDf.CID.unique())
# Out:
# 557

# %%
df = DataCleaner.getRepoInfoDfByCid(companyDf, 29, True)

# %%
a = DataCleaner.getRepoInfoInYear(df, 2020)
b = {}
for _ in a.items():
    key, value = _
    b['Matched ' + key] = value
# Out:
# {'Matched Forks': 50759.0,
#  'Matched Stars': 231121.0,
#  'Matched Watchers': 231121.0,
#  'Matched Commits': 415188.0,
#  'Matched Branches': 14233.0,
#  'Matched Contributors': 10130.0,
#  'Matched Open Issues': 12991.0,
#  'Matched PullRequests': 4118.0,
#  'Matched Repos Created': 836}

# %%
DataCleaner.analyzeByCid(companyDf, 29, [2020, 2021, 2022])
# Out:
#    CID  Year  MatchedPapers  TotalPapers    Forks     Stars  Watchers  \
# 0   29  2020             61         1933  50759.0  231121.0  231121.0
# 1   29  2021             81         1918  34367.0  176673.0  176673.0
# 2   29  2022             51         1588   6907.0   40215.0   40215.0
#
#      Commits  Branches  Contributors  ...  Repos Created  Matched Forks  \
# 0   415188.0   14233.0       10130.0  ...            836         4191.0
# 1  2193218.0    6789.0        8445.0  ...            814         3708.0
# 2   306395.0    5231.0        5971.0  ...            900          220.0
#
#    Matched Stars  Matched Watchers  Matched Commits  Matched Branches  \
# 0        23300.0           23300.0           3348.0             239.0
# 1        24537.0           24537.0           4947.0             223.0
# 2         1664.0            1664.0            689.0              56.0
#
#    Matched Contributors  Matched Open Issues  Matched PullRequests  \
# 0                 267.0                750.0                  77.0
# 1                 340.0                743.0                 107.0
# 2                  73.0                103.0                  34.0
#
#    Matched Repos Created
# 0                     48
# 1                     70
# 2                     19
#
# [3 rows x 22 columns]

# %%
bigDS = DataCleaner.getInfoDfFromCidAndYear(companyDf)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:26<00:00, 21.06it/s]

# %%
bigDS.to_csv('DataByCIDAndYearV2.csv', index=False)

# %%
matchedPaperInfo = DataCleaner.getAllMatchingPapersInfo(companyDf)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:11<00:00, 47.07it/s]

# %%
matchedPaperInfo.to_csv('matched_papersV2.csv', index = False)

# %%
paperTitles = [title.lower() for title in companyDf['Title']]
matchedPapers = pwc[pwc['paper_title'].str.lower().isin(paperTitles)]

# %%
pd.DataFrame(columns=['Full Name','Forks','Stars','Watchers','Commits','Branches','Contributors','Open Issues','PullRequests','YearCreated'])
# Out:
# Empty DataFrame
# Columns: [Full Name, Forks, Stars, Watchers, Commits, Branches, Contributors, Open Issues, PullRequests, YearCreated]
# Index: []

# %%
len(matchedPapers)
# Out:
# 26373

# %%
matchedPapersFromGithub = DataTools.loadCSVFromOutput('finalStuff/matched_papersV2')

# %%
len(matchedPapersFromGithub)
# Out:
# 1185

# %%
for _ in matchedPapers:
# Out:
#                                                 paper_url  \
# 2       https://paperswithcode.com/paper/attngan-fine-...
# 9       https://paperswithcode.com/paper/bottom-up-and...
# 10      https://paperswithcode.com/paper/trust-pcl-an-...
# 13      https://paperswithcode.com/paper/faster-r-cnn-...
# 15      https://paperswithcode.com/paper/bridging-the-...
# ...                                                   ...
# 185376  https://paperswithcode.com/paper/asynchronous-...
# 185381  https://paperswithcode.com/paper/learning-coop...
# 185383  https://paperswithcode.com/paper/quo-vadis-act...
# 185385  https://paperswithcode.com/paper/recurrent-neu...
# 185386  https://paperswithcode.com/paper/bag-of-tricks...
#
#                                               paper_title paper_arxiv_id  \
# 2       AttnGAN: Fine-Grained Text to Image Generation...     1711.10485
# 9       Bottom-Up and Top-Down Attention for Image Cap...     1707.07998
# 10      Trust-PCL: An Off-Policy Trust Region Method f...     1707.01891
# 13      Faster R-CNN: Towards Real-Time Object Detecti...     1506.01497
# 15      Bridging the Gap Between Value and Policy Base...     1702.08892
# ...                                                   ...            ...
# 185376  Asynchronous Methods for Deep Reinforcement Le...     1602.01783
# 185381  Learning Cooperative Visual Dialog Agents with...     1703.06585
# 185383  Quo Vadis, Action Recognition? A New Model and...     1705.07750
# 185385  Recurrent Neural Networks with Top-k Gains for...     1706.03847
# 185386  Bag of Tricks for Image Classification with Co...     1812.01187
#
#                             paper_url_abs  \
# 2       http://arxiv.org/abs/1711.10485v1
# 9       http://arxiv.org/abs/1707.07998v3
# 10      http://arxiv.org/abs/1707.01891v3
# 13      http://arxiv.org/abs/1506.01497v3
# 15      http://arxiv.org/abs/1702.08892v3
# ...                                   ...
# 185376  http://arxiv.org/abs/1602.01783v2
# 185381  http://arxiv.org/abs/1703.06585v2
# 185383  http://arxiv.org/abs/1705.07750v3
# 185385  http://arxiv.org/abs/1706.03847v3
# 185386  http://arxiv.org/abs/1812.01187v2
#
#                                 paper_url_pdf  \
# 2       http://arxiv.org/pdf/1711.10485v1.pdf
# 9       http://arxiv.org/pdf/1707.07998v3.pdf
# 10      http://arxiv.org/pdf/1707.01891v3.pdf
# 13      http://arxiv.org/pdf/1506.01497v3.pdf
# 15      http://arxiv.org/pdf/1702.08892v3.pdf
# ...                                       ...
# 185376  http://arxiv.org/pdf/1602.01783v2.pdf
# 185381  http://arxiv.org/pdf/1703.06585v2.pdf
# 185383  http://arxiv.org/pdf/1705.07750v3.pdf
# 185385  http://arxiv.org/pdf/1706.03847v3.pdf
# 185386  http://arxiv.org/pdf/1812.01187v2.pdf
#
#                                                  repo_url  is_official  \
# 2             https://github.com/bprabhakar/text-to-image        False
# 9        https://github.com/feifengwhu/question_attention        False
# 10                   https://github.com/tensorflow/models         True
# 13        https://github.com/vincentzhang/faster-rcnn-fcn        False
# 15                   https://github.com/tensorflow/models         True
# ...                                                   ...          ...
# 185376  https://github.com/Jventajas/Reinforcement-Lea...        False
# 185381               https://github.com/Cremiy/visdial-rl        False
# 185383           https://github.com/deepmind/kinetics-i3d        False
# 185385            https://github.com/pcerdam/KerasGRU4Rec        False
# 185386  https://github.com/CryptoSalamander/pytorch_pa...        False
#
#         mentioned_in_paper  mentioned_in_github framework
# 2                    False                False   pytorch
# 9                    False                 True   pytorch
# 10                    True                False        tf
# 13                   False                 True      none
# 15                    True                False        tf
# ...                    ...                  ...       ...
# 185376               False                 True        tf
# 185381               False                 True   pytorch
# 185383               False                 True        tf
# 185385               False                 True        tf
# 185386               False                 True   pytorch
#
# [26373 rows x 10 columns]

# %%
dataByCid = DataTools.loadCSVFromOutput('finalStuff/DataByCIDAndYearV2')

# %%
len(dataByCid[dataByCid.MatchedPapers > 0].CID.unique())
# Out:
# 68

# %%
len(companyDf.CID.unique())
# Out:
# 557

# %%
usernames = []
for _ in Extractor.getConfig():
    a = ['/' + username + '/' for username in _['repos']]
    usernames.extend(a)

# %%
matchedByCompany = matchedPapers[matchedPapers.repo_url.str.contains('|'.join(usernames))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 matchedByCompany = matchedPapers[matchedPapers.repo_url.str.contains('|'.join(usernames))]
#
# NameError: name 'matchedPapers' is not defined

# %%
len(matchedByCompany)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 len(matchedByCompany)
#
# NameError: name 'matchedByCompany' is not defined

# %%
paperTitles = [title.lower() for title in pwc['paper_title']]
matchedPapers2 = companyDf[companyDf['Title'].str.lower().isin(paperTitles)]

# %%
len(matchedPapers2.CID.unique())
# Out:
# 225

# %%
repo_urls = list(pwc.repo_url)

# %%
import re
link_pattern = r'https://github.com/([\w\-]*)/[\w\-]*'

usernames = [re.findall(link_pattern, repo_url)[0] for repo_url in repo_urls if len(re.findall(link_pattern, repo_url)) > 0]

# %%
from collections import Counter
usernames_count = Counter(usernames)

# %%
usernames_count.most_common()
# Out:
# [('facebookresearch', 1228),
#  ('microsoft', 686),
#  ('google-research', 640),
#  ('PaddlePaddle', 624),
#  ('tensorflow', 372),
#  ('open-mmlab', 346),
#  ('mindspore-ai', 284),
#  ('google', 231),
#  ('deepmind', 219),
#  ('2023-MindSpore-1', 219),
#  ('cran', 207),
#  ('IBM', 202),
#  ('allenai', 194),
#  ('lucidrains', 184),
#  ('huggingface', 152),
#  ('Mind23-2', 149),
#  ('thunlp', 140),
#  ('yangyucheng000', 135),
#  ('salesforce', 134),
#  ('pytorch', 130),
#  ('alibaba', 125),
#  ('benedekrozemberczki', 125),
#  ('amazon-research', 119),
#  ('dmlc', 116),
#  ('huawei-noah', 114),
#  ('NVlabs', 110),
#  ('UKPLab', 108),
#  ('rwightman', 103),
#  ('osmr', 103),
#  ('cair', 101),
#  ('UnofficialJuliaMirrorSnapshots', 100),
#  ('UnofficialJuliaMirror', 99),
#  ('megvii-research', 88),
#  ('openai', 86),
#  ('NVIDIA', 85),
#  ('google-research-datasets', 81),
#  ('awslabs', 80),
#  ('keonlee9420', 78),
#  ('clovaai', 76),
#  ('Microsoft', 74),
#  ('thuml', 73),
#  ('ibm', 73),
#  ('shenweichen', 73),
#  ('xiuyu0000', 72),
#  ('boschresearch', 70),
#  ('lancopku', 68),
#  ('locuslab', 68),
#  ('sisl', 66),
#  ('automl', 66),
#  ('ermongroup', 65),
#  ('opendilab', 65),
#  ('idiap', 63),
#  ('rickyHong', 62),
#  ('dvlab-research', 62),
#  ('labmlai', 62),
#  ('Guang000', 61),
#  ('kingcong', 59),
#  ('ethz-asl', 58),
#  ('leondgarse', 56),
#  ('jackaduma', 56),
#  ('lyqcom', 55),
#  ('naver', 54),
#  ('apple', 53),
#  ('vita-group', 53),
#  ('valeoai', 53),
#  ('vanderschaarlab', 51),
#  ('thu-coai', 51),
#  ('eriklindernoren', 51),
#  ('HKUST-KnowComp', 50),
#  ('Westlake-AI', 50),
#  ('marload', 49),
#  ('VITA-Group', 49),
#  ('webis-de', 49),
#  ('uzh-rpg', 49),
#  ('ctuning', 48),
#  ('basiralab', 48),
#  ('xue-pai', 48),
#  ('zjunlp', 48),
#  ('olivesgatech', 47),
#  ('mit-han-lab', 47),
#  ('BR-IDL', 46),
#  ('imatge-upc', 45),
#  ('alililia', 45),
#  ('pfnet-research', 45),
#  ('nvlabs', 45),
#  ('bradkav', 45),
#  ('cvxgrp', 44),
#  ('gmum', 44),
#  ('lemire', 44),
#  ('val-iisc', 43),
#  ('anton-petrunin', 43),
#  ('bghojogh', 43),
#  ('declare-lab', 42),
#  ('snap-stanford', 42),
#  ('kakaobrain', 42),
#  ('eth-sri', 42),
#  ('hustvl', 41),
#  ('Qengineering', 41),
#  ('princeton-nlp', 41),
#  ('bcmi', 41),
#  ('castorini', 41),
#  ('gwastro', 40),
#  ('INK-USC', 40),
#  ('epfl-dlab', 40),
#  ('rishikksh20', 40),
#  ('Sakib1263', 40),
#  ('alan-turing-institute', 40),
#  ('huanzhang12', 40),
#  ('Stick-To', 39),
#  ('uber-research', 39),
#  ('naver-ai', 39),
#  ('jiajunhua', 39),
#  ('vita-epfl', 38),
#  ('THUDM', 38),
#  ('usnistgov', 38),
#  ('Burf', 38),
#  ('yoshitomo-matsubara', 38),
#  ('HazyResearch', 37),
#  ('deeplearning-wisc', 37),
#  ('StanfordASL', 37),
#  ('researchmm', 36),
#  ('neulab', 36),
#  ('QData', 36),
#  ('autonomousvision', 36),
#  ('pnnl', 36),
#  ('epfml', 36),
#  ('sayakpaul', 36),
#  ('MiuLab', 36),
#  ('sooftware', 36),
#  ('towhee-io', 36),
#  ('divelab', 35),
#  ('nju-websoft', 35),
#  ('ictnlp', 35),
#  ('uoe-agents', 35),
#  ('hkust-knowcomp', 35),
#  ('zhaoolee', 35),
#  ('slimgroup', 35),
#  ('XanaduAI', 35),
#  ('yqx7150', 34),
#  ('deep-spin', 34),
#  ('oliverphilcox', 34),
#  ('princeton-vl', 34),
#  ('amazon-science', 34),
#  ('aspuru-guzik-group', 34),
#  ('layumi', 34),
#  ('ku2482', 34),
#  ('Lcrypto', 33),
#  ('uds-lsv', 33),
#  ('emilbjornson', 33),
#  ('TsingZ0', 33),
#  ('nbatfai', 33),
#  ('csinva', 33),
#  ('learn-co-students', 33),
#  ('IntelLabs', 32),
#  ('ml-research', 32),
#  ('CMU-SAFARI', 32),
#  ('Lornatang', 32),
#  ('MaximeVandegar', 32),
#  ('amzn', 32),
#  ('bytedance', 32),
#  ('tensorpack', 31),
#  ('mit-acl', 31),
#  ('rycolab', 31),
#  ('MIT-SPARK', 31),
#  ('MadryLab', 31),
#  ('rucaibox', 31),
#  ('alexa', 31),
#  ('deezer', 31),
#  ('sithu31296', 31),
#  ('lvyufeng', 31),
#  ('LONG-9621', 31),
#  ('ukplab', 31),
#  ('xmu-xiaoma666', 30),
#  ('YeongHyeon', 30),
#  ('lanl', 30),
#  ('thudm', 30),
#  ('conceptofmind', 30),
#  ('poloclub', 30),
#  ('HiLab-git', 30),
#  ('ChristophReich1996', 30),
#  ('Deci-AI', 30),
#  ('vision4robotics', 29),
#  ('dmis-lab', 29),
#  ('taki0112', 29),
#  ('cambridgeltl', 29),
#  ('bethgelab', 29),
#  ('signetlabdei', 29),
#  ('hz-ants', 29),
#  ('flowersteam', 29),
#  ('ray-project', 29),
#  ('cmendl', 29),
#  ('xqx12', 29),
#  ('dice-group', 28),
#  ('Ha0Tang', 28),
#  ('mindspore-ecosystem', 28),
#  ('iesl', 28),
#  ('clinicalml', 28),
#  ('cmu-safari', 28),
#  ('kclip', 28),
#  ('D-X-Y', 28),
#  ('BorealisAI', 28),
#  ('ruotianluo', 28),
#  ('ml-jku', 28),
#  ('frgfm', 28),
#  ('titu1994', 27),
#  ('nyu-dl', 27),
#  ('keras-team', 27),
#  ('CompNet', 27),
#  ('SHI-Labs', 27),
#  ('hku-mars', 27),
#  ('HRNet', 27),
#  ('hazyresearch', 27),
#  ('qilei123', 27),
#  ('harvardnlp', 27),
#  ('eric-erki', 27),
#  ('modelscope', 27),
#  ('clementchadebec', 27),
#  ('makcedward', 27),
#  ('dair-iitd', 26),
#  ('StanfordVL', 26),
#  ('ZJULearning', 26),
#  ('cambridge-mlg', 26),
#  ('aimagelab', 26),
#  ('ElementAI', 26),
#  ('openvinotoolkit', 26),
#  ('thuiar', 26),
#  ('spcl', 26),
#  ('AI-secure', 26),
#  ('ostadabbas', 26),
#  ('aim-uofa', 26),
#  ('stochasticHydroTools', 26),
#  ('KarhouTam', 26),
#  ('JunnYu', 25),
#  ('espnet', 25),
#  ('asappresearch', 25),
#  ('VinAIResearch', 25),
#  ('ufal', 25),
#  ('DLR-RM', 25),
#  ('zju3dv', 25),
#  ('nii-yamagishilab', 25),
#  ('soarsmu', 25),
#  ('cda-tum', 25),
#  ('DengPingFan', 25),
#  ('nyu-mll', 25),
#  ('dwinney', 25),
#  ('coqui-ai', 25),
#  ('neurodata', 24),
#  ('TAMU-VITA', 24),
#  ('mahmoudnafifi', 24),
#  ('utiasSTARS', 24),
#  ('sail-sg', 24),
#  ('yandex-research', 24),
#  ('pulp-platform', 24),
#  ('iitis', 24),
#  ('layer6ai-labs', 24),
#  ('uclanlp', 24),
#  ('MIC-DKFZ', 24),
#  ('AemikaChow', 24),
#  ('ibaiGorordo', 23),
#  ('dtak', 23),
#  ('massquantity', 23),
#  ('JoegameZhou', 23),
#  ('LCS2-IIITD', 23),
#  ('stanfordnlp', 23),
#  ('uhh-lt', 23),
#  ('ncbi-nlp', 23),
#  ('NervanaSystems', 23),
#  ('nusnlp', 22),
#  ('Kaixhin', 22),
#  ('JunweiLiang', 22),
#  ('LLNL', 22),
#  ('deepmipt', 22),
#  ('nttcslab', 22),
#  ('bzhangGo', 22),
#  ('rosinality', 22),
#  ('PRBonn', 22),
#  ('visinf', 22),
#  ('JonasGeiping', 22),
#  ('kornia', 22),
#  ('aliborji', 22),
#  ('tencent-ailab', 22),
#  ('chandar-lab', 22),
#  ('kevinmusgrave', 22),
#  ('Acicone', 22),
#  ('coastalcph', 22),
#  ('yzhao062', 22),
#  ('Koukyosyumei', 22),
#  ('midas-research', 21),
#  ('AKASH2907', 21),
#  ('HKUST-Aerial-Robotics', 21),
#  ('CompVis', 21),
#  ('szq0214', 21),
#  ('inspire-group', 21),
#  ('smsharma', 21),
#  ('stanford-futuredata', 21),
#  ('vitae-transformer', 21),
#  ('zju-vipa', 21),
#  ('mcg-nju', 21),
#  ('martius-lab', 21),
#  ('BY571', 21),
#  ('fgnt', 21),
#  ('ltgoslo', 21),
#  ('bigscience-workshop', 21),
#  ('freedombenLiu', 21),
#  ('megagonlabs', 21),
#  ('alinlab', 21),
#  ('malllabiisc', 21),
#  ('baidu', 21),
#  ('swz30', 21),
#  ('TencentYoutuResearch', 21),
#  ('uncbiag', 21),
#  ('nv-tlabs', 21),
#  ('mindslab-ai', 21),
#  ('beresandras', 21),
#  ('JDAI-CV', 20),
#  ('illidanlab', 20),
#  ('ducha-aiki', 20),
#  ('wenhuchen', 20),
#  ('vinits5', 20),
#  ('ratschlab', 20),
#  ('wangxiao5791509', 20),
#  ('thu-ml', 20),
#  ('showlab', 20),
#  ('LKLQQ', 20),
#  ('stanfordasl', 20),
#  ('vinairesearch', 20),
#  ('csiro-robotics', 20),
#  ('yxgeee', 20),
#  ('ShannonAI', 20),
#  ('sydney-machine-learning', 20),
#  ('emorynlp', 20),
#  ('Mayurji', 20),
#  ('iic-jku', 20),
#  ('Rishit-dagli', 20),
#  ('hikvision-research', 20),
#  ('CogComp', 20),
#  ('KaiyangZhou', 20),
#  ('kamperh', 20),
#  ('facebook', 19),
#  ('chainer', 19),
#  ('sshonosuke', 19),
#  ('CausalML', 19),
#  ('jingtaozhan', 19),
#  ('stanfordmlgroup', 19),
#  ('hep-lbdl', 19),
#  ('astro-informatics', 19),
#  ('jeromerony', 19),
#  ('iamalexkorotin', 19),
#  ('sberbank-ai', 19),
#  ('pminhtam', 19),
#  ('cogsys-tuebingen', 19),
#  ('bupt-ai-cz', 19),
#  ('mathLab', 19),
#  ('hendrycks', 19),
#  ('ubc-vision', 19),
#  ('IPL-UV', 19),
#  ('SAP-samples', 19),
#  ('tum-pbs', 19),
#  ('0jason000', 19),
#  ('frankaging', 19),
#  ('ds4dm', 19),
#  ('zhusiling', 19),
#  ('MCG-NJU', 19),
#  ('TooTouch', 19),
#  ('ZJU-FAST-Lab', 19),
#  ('UMich-BipedLab', 19),
#  ('zalandoresearch', 19),
#  ('plai-group', 19),
#  ('SamsungLabs', 19),
#  ('proroklab', 19),
#  ('CtrlZ1', 19),
#  ('zhanghang1989', 19),
#  ('wang-chen', 19),
#  ('vlvovch', 19),
#  ('deepinsight', 19),
#  ('jacobgil', 19),
#  ('RingBDStack', 19),
#  ('Kyubyong', 19),
#  ('raun1', 19),
#  ('cvlab-stonybrook', 19),
#  ('camma-public', 19),
#  ('huseinzol05', 19),
#  ('serengil', 19),
#  ('Tencent', 18),
#  ('qq456cvb', 18),
#  ('AntixK', 18),
#  ('HLTCHKUST', 18),
#  ('reactive-systems', 18),
#  ('mv-lab', 18),
#  ('mdrafiqulrabin', 18),
#  ('EpistasisLab', 18),
#  ('neurai-lab', 18),
#  ('princetonvisualai', 18),
#  ('fudan-zvg', 18),
#  ('DeepGraphLearning', 18),
#  ('cvlab-epfl', 18),
#  ('sharathadavanne', 18),
#  ('woodyx218', 18),
#  ('se2p', 18),
#  ('woctezuma', 18),
#  ('jungokasai', 18),
#  ('shizuo-kaji', 18),
#  ('dfki-nlp', 18),
#  ('lil-lab', 18),
#  ('brain-research', 18),
#  ('clvrai', 18),
#  ('jaketae', 18),
#  ('LSSTDESC', 18),
#  ('JetBrains-Research', 18),
#  ('adaptive-intelligent-robotics', 18),
#  ('leaplabthu', 18),
#  ('baggepinnen', 18),
#  ('kailaix', 18),
#  ('lightly-ai', 18),
#  ('JonasRSV', 18),
#  ('ChengBinJin', 18),
#  ('alibaba-damo-academy', 18),
#  ('DarshanDeshpande', 18),
#  ('intellabs', 18),
#  ('liuruiyang98', 18),
#  ('g-u-n', 18),
#  ('Soumyabrata', 17),
#  ('guoyongcs', 17),
#  ('Networks-Learning', 17),
#  ('DeepLearnXMU', 17),
#  ('YuanGongND', 17),
#  ('VCL3D', 17),
#  ('Jia-Research-Lab', 17),
#  ('lanl-ansi', 17),
#  ('rajeshrinet', 17),
#  ('BorgwardtLab', 17),
#  ('tianhai123', 17),
#  ('xiaoh', 17),
#  ('timeseriesAI', 17),
#  ('daochenzha', 17),
#  ('BiDAlab', 17),
#  ('ikostrikov', 17),
#  ('clips', 17),
#  ('jiesutd', 17),
#  ('astorfi', 17),
#  ('EugenHotaj', 17),
#  ('icecube', 17),
#  ('deepsphere', 17),
#  ('seemoo-lab', 17),
#  ('unstable-zeros', 17),
#  ('mahdihosseini', 17),
#  ('prajjwal1', 17),
#  ('idea-research', 17),
#  ('ziatdinovmax', 17),
#  ('ModelOriented', 17),
#  ('COMP6248-Reproducability-Challenge', 17),
#  ('yiskw713', 17),
#  ('jayleicn', 17),
#  ('maziarraissi', 17),
#  ('lmb-freiburg', 17),
#  ('imperial-qore', 17),
#  ('baturaysaglam', 17),
#  ('eyalbetzalel', 17),
#  ('leggedrobotics', 17),
#  ('DataScienceNigeria', 17),
#  ('msalhab96', 17),
#  ('cuhksz-nlp', 17),
#  ('brightmart', 17),
#  ('buds-lab', 17),
#  ('ymcui', 17),
#  ('cbpark', 17),
#  ('asarigun', 17),
#  ('idsia', 17),
#  ('cleverhans-lab', 17),
#  ('erichson', 17),
#  ('Media-Smart', 17),
#  ('czarmanu', 17),
#  ('baidu-research', 16),
#  ('Helsinki-NLP', 16),
#  ('HCPLab-SYSU', 16),
#  ('l294265421', 16),
#  ('danifg', 16),
#  ('scikit-learn-contrib', 16),
#  ('XinshaoAmosWang', 16),
#  ('uoguelph-mlrg', 16),
#  ('soumik12345', 16),
#  ('DelMaestroGroup', 16),
#  ('genforce', 16),
#  ('omron-sinicx', 16),
#  ('RoaringBitmap', 16),
#  ('jviquerat', 16),
#  ('megvii-model', 16),
#  ('tencentarc', 16),
#  ('samson6460', 16),
#  ('CMU-Perceptual-Computing-Lab', 16),
#  ('lululxvi', 16),
#  ('oxwhirl', 16),
#  ('sony', 16),
#  ('skoltech-nlp', 16),
#  ('philipperemy', 16),
#  ('mlvlab', 16),
#  ('git-disl', 16),
#  ('fra31', 16),
#  ('CRIPAC-DIG', 16),
#  ('AIS-Bonn', 16),
#  ('yaxingwang', 16),
#  ('zjZSTU', 16),
#  ('hltchkust', 16),
#  ('mszpc', 16),
#  ('ryojitanabe', 16),
#  ('iai-group', 16),
#  ('lucylow', 16),
#  ('dobriban', 16),
#  ('rozumden', 16),
#  ('AutoML-4Paradigm', 16),
#  ('Unbabel', 16),
#  ('s3prl', 16),
#  ('fakenmc', 16),
#  ('mikahama', 16),
#  ('ShangtongZhang', 16),
#  ('CoinCheung', 16),
#  ('pliang279', 16),
#  ('alibabaresearch', 16),
#  ('ai-med', 16),
#  ('codersguild', 16),
#  ('ContinualAI', 16),
#  ('achael', 16),
#  ('glouppe', 16),
#  ('jim-schwoebel', 16),
#  ('DataCanvasIO', 16),
#  ('mravanelli', 15),
#  ('ivalab', 15),
#  ('bplank', 15),
#  ('jindongwang', 15),
#  ('DPBayes', 15),
#  ('patrick-kidger', 15),
#  ('IVRL', 15),
#  ('lukemelas', 15),
#  ('probcomp', 15),
#  ('dos-group', 15),
#  ('CPJKU', 15),
#  ('doerlbh', 15),
#  ('zjukg', 15),
#  ('icaros-usc', 15),
#  ('snap-research', 15),
#  ('RUCAIBox', 15),
#  ('hiroyuki-kasai', 15),
#  ('chaitjo', 15),
#  ('keunwoochoi', 15),
#  ('1adrianb', 15),
#  ('lxtGH', 15),
#  ('RICE-EIC', 15),
#  ('eXascaleInfolab', 15),
#  ('ipc-lab', 15),
#  ('sapienzanlp', 15),
#  ('swing-research', 15),
#  ('majianthu', 15),
#  ('dvl-tum', 15),
#  ('revsic', 15),
#  ('EmmanuelSchaan', 15),
#  ('ofsoundof', 15),
#  ('juglab', 15),
#  ('tech-srl', 15),
#  ('renyang-home', 15),
#  ('PennyLaneAI', 15),
#  ('alexandra-chron', 15),
#  ('huckiyang', 15),
#  ('svip-lab', 15),
#  ('copenlu', 15),
#  ('Fraunhofer-AISEC', 15),
#  ('zrrskywalker', 15),
#  ('vturrisi', 15),
#  ('xmed-lab', 15),
#  ('verlab', 15),
#  ('alshedivat', 15),
#  ('tensorlayer', 15),
#  ('pluslabnlp', 15),
#  ('GT-RIPL', 15),
#  ('ucfnlp', 15),
#  ('batra-mlp-lab', 15),
#  ('cltl', 15),
#  ('terrierteam', 15),
#  ('adobe-research', 15),
#  ('ielab', 15),
#  ('UCSD-AI4H', 15),
#  ('gebob19', 15),
#  ('VisionLearningGroup', 15),
#  ('testingautomated-usi', 15),
#  ('yaoyao-liu', 15),
#  ('vered1986', 15),
#  ('Thinklab-SJTU', 15),
#  ('HumanCompatibleAI', 15),
#  ('ZhijieXu2022', 15),
#  ('human-analysis', 15),
#  ('eleurent', 15),
#  ('krantirk', 15),
#  ('lavoiems', 15),
#  ('gregversteeg', 15),
#  ('ucsd-dsc-arts', 15),
#  ('tdhock', 15),
#  ('ttt496', 15),
#  ('JoschUniHD', 15),
#  ('hill-a', 15),
#  ('lmbxmu', 15),
#  ('caiyuanhao1998', 15),
#  ('ryuikaneko', 15),
#  ('intel', 15),
#  ('SforAiDl', 15),
#  ('vios-s', 14),
#  ('mks0601', 14),
#  ('sckangz', 14),
#  ('huangleiBuaa', 14),
#  ('zhihou7', 14),
#  ('soc-ucsd', 14),
#  ('nyukat', 14),
#  ('isl-org', 14),
#  ('barbagroup', 14),
#  ('stefan-it', 14),
#  ('sacmehta', 14),
#  ('winycg', 14),
#  ('yxuansu', 14),
#  ('songhan', 14),
#  ('black0017', 14),
#  ('sfu-cosmo', 14),
#  ('hysts', 14),
#  ('dipjyoti92', 14),
#  ('AaltoVision', 14),
#  ('Stanford-ILIAD', 14),
#  ('bagustris', 14),
#  ('nebblu', 14),
#  ('PyFE', 14),
#  ('fzi-forschungszentrum-informatik', 14),
#  ('yang-song', 14),
#  ('CIA-Oceanix', 14),
#  ('cleanlab', 14),
#  ('uber', 14),
#  ('ai-se', 14),
#  ('LynnHo', 14),
#  ('mitre', 14),
#  ('Spirals-Team', 14),
#  ('GatorSense', 14),
#  ('TensorSpeech', 14),
#  ('learningmatter-mit', 14),
#  ('foamliu', 14),
#  ('mees', 14),
#  ('brandontrabucco', 14),
#  ('clason', 14),
#  ('alipay', 14),
#  ('dmcv-ecnu', 14),
#  ('DingXiaoH', 14),
#  ('zju-fast-lab', 14),
#  ('linxi159', 14),
#  ('shyhyawJou', 14),
#  ('wangjie212', 14),
#  ('soumickmj', 14),
#  ('nveldt', 14),
#  ('mikekatz04', 14),
#  ('moucheng2017', 14),
#  ('mashaan14', 14),
#  ('rwth-i6', 14),
#  ('ispamm', 14),
#  ('abhilash1910', 14),
#  ('daiquocnguyen', 14),
#  ('AstraZeneca', 14),
#  ('JHL-HUST', 14),
#  ('icon-lab', 14),
#  ('Shraddha2013', 14),
#  ('mila-iqia', 14),
#  ('daschaich', 14),
#  ('aioz-ai', 14),
#  ('resibots', 14),
#  ('epic-kitchens', 14),
#  ('CAMMA-public', 14),
#  ('bayesgroup', 14),
#  ('thu-spmi', 14),
#  ('timoschick', 14),
#  ('asahi417', 14),
#  ('IRVLab', 14),
#  ('seominseok0429', 14),
#  ('jbdel', 14),
#  ('vohoaiviet', 14),
#  ('robotology', 14),
#  ('kritiksoman', 14),
#  ('pralab', 14),
#  ('reggiebernardo', 14),
#  ('jiahuei', 14),
#  ('JohannesBuchner', 14),
#  ('shinya7y', 14),
#  ('JanMarcelKezmann', 14),
#  ('tudelft', 14),
#  ('martiansideofthemoon', 14),
#  ('graykode', 14),
#  ('yuzhimanhua', 13),
#  ('ananyahjha93', 13),
#  ('polimi-ispl', 13),
#  ('threelittlemonkeys', 13),
#  ('etzinis', 13),
#  ('ivclab', 13),
#  ('davidstutz', 13),
#  ('misho104', 13),
#  ('HUJI-Deep', 13),
#  ('uclnlp', 13),
#  ('pietrobarbiero', 13),
#  ('amirgholami', 13),
#  ('googleinterns', 13),
#  ('xuhongzuo', 13),
#  ('aistairc', 13),
#  ('Ildaron', 13),
#  ('qiuqiangkong', 13),
#  ('Babylonpartners', 13),
#  ('ranocha', 13),
#  ('ppernot', 13),
#  ('jhl-hust', 13),
#  ('joisino', 13),
#  ('castor-software', 13),
#  ('jamycheung', 13),
#  ('david-cortes', 13),
#  ('hltcoe', 13),
#  ('explainableml', 13),
#  ('galsang', 13),
#  ('hkust-aerial-robotics', 13),
#  ('opengvlab', 13),
#  ('hate-alert', 13),
#  ('gurkirt', 13),
#  ('barisbatuhan', 13),
#  ('danini', 13),
#  ('quantumlib', 13),
#  ('sbelharbi', 13),
#  ('mackelab', 13),
#  ('cvjena', 13),
#  ('The-AI-Summer', 13),
#  ('rusty1s', 13),
#  ('alexandrosstergiou', 13),
#  ('intel-isl', 13),
#  ('safe-graph', 13),
#  ('nianticlabs', 13),
#  ('acmi-lab', 13),
#  ('CSAILVision', 13),
#  ('mlmed', 13),
#  ('IceCubeOpenSource', 13),
#  ('DevSinghSachan', 13),
#  ('sicara', 13),
#  ('csebuetnlp', 13),
#  ('sense-x', 13),
#  ('UCLA-StarAI', 13),
#  ('datamllab', 13),
#  ('yangheng95', 13),
#  ('lcs2-iiitd', 13),
#  ('TanyaChutani', 13),
#  ('hannorein', 13),
#  ('meelgroup', 13),
#  ('Confusezius', 13),
#  ('frankkramer-lab', 13),
#  ('stanford-oval', 13),
#  ('modelhub-ai', 13),
#  ('mobarakol', 13),
#  ('huaxiuyao', 13),
#  ('med-air', 13),
#  ('caskcsg', 13),
#  ('thu-keg', 13),
#  ('tinkoff-ai', 13),
#  ('nexus-lab', 13),
#  ('tnagler', 13),
#  ('mainlp', 13),
#  ('VisualComputingInstitute', 13),
#  ('Guillem96', 13),
#  ('abhinavsagar', 13),
#  ('adapt-python', 13),
#  ('softsys4ai', 13),
#  ('lupalab', 13),
#  ('BBillot', 13),
#  ('morningmoni', 13),
#  ('giannisdaras', 13),
#  ('oxfordcontrol', 13),
#  ('iiscleap', 13),
#  ('batmanlab', 13),
#  ('zhengy09', 13),
#  ('nitishmital', 13),
#  ('Georgetown-IR-Lab', 13),
#  ('srihari-humbarwadi', 13),
#  ('teddykoker', 13),
#  ('ashawkey', 13),
#  ('Zzh-tju', 13),
#  ('benywon', 13),
#  ('mmasana', 13),
#  ('DS3Lab', 13),
#  ('hfawaz', 13),
#  ('carbonati', 13),
#  ('cselab', 13),
#  ('cunningham-lab', 13),
#  ('spring-epfl', 13),
#  ('jqueguiner', 13),
#  ('EdinburghNLP', 13),
#  ('Zhiwei-Z', 13),
#  ('hongxin001', 13),
#  ('bcmi220', 13),
#  ('akononovicius', 13),
#  ('CGCL-codes', 13),
#  ('jankrepl', 13),
#  ('KangchengLiu', 13),
#  ('dynamicslab', 13),
#  ('Cadene', 13),
#  ('IssamLaradji', 13),
#  ('rohban-lab', 13),
#  ('LiamMaclean216', 13),
#  ('jwzhanggy', 13),
#  ('STEllAR-GROUP', 13),
#  ('hkunlp', 13),
#  ('mpariente', 13),
#  ('ZurichNLP', 13),
#  ('mingsun-tse', 13),
#  ('usc-sail', 13),
#  ('cvqluu', 13),
#  ('cryu854', 13),
#  ('cc-hpc-itwm', 13),
#  ('wq2012', 13),
#  ('stepjam', 13),
#  ('MickaelRigault', 13),
#  ('ftheberge', 13),
#  ('shiqiyu', 13),
#  ('hanzhanggit', 13),
#  ('budzianowski', 13),
#  ('IDEA-Research', 13),
#  ('martinsbruveris', 13),
#  ('chengtan9907', 13),
#  ('sangyun884', 13),
#  ('learnables', 13),
#  ('ybayle', 13),
#  ('sagieppel', 12),
#  ('irom-lab', 12),
#  ('dgerosa', 12),
#  ('PoulinV', 12),
#  ('MegEngine', 12),
#  ('georgestein', 12),
#  ('DirtyHarryLYL', 12),
#  ('Avmb', 12),
#  ('harsh19', 12),
#  ('xahidbuffon', 12),
#  ('saeed-anwar', 12),
#  ('PlusLabNLP', 12),
#  ('aws-samples', 12),
#  ('nikhilroxtomar', 12),
#  ('UdbhavPrasad072300', 12),
#  ('hkzhang91', 12),
#  ('jiean001', 12),
#  ('chingyaoc', 12),
#  ('rktamplayo', 12),
#  ('princeton-computational-imaging', 12),
#  ('robot-learning-freiburg', 12),
#  ('dessertlab', 12),
#  ('ucsc-real', 12),
#  ('facebookarchive', 12),
#  ('haoheliu', 12),
#  ('gaopengcuhk', 12),
#  ('fiveai', 12),
#  ('tranhungnghiep', 12),
#  ('wasiahmad', 12),
#  ('mlfoundations', 12),
#  ('eminorhan', 12),
#  ('jermp', 12),
#  ('nnaisense', 12),
#  ('tufts-ml', 12),
#  ('tkipf', 12),
#  ('ftramer', 12),
#  ('DanielLongo', 12),
#  ('SenticNet', 12),
#  ('lonePatient', 12),
#  ('AlexiaJM', 12),
#  ('inzva', 12),
#  ('antoine77340', 12),
#  ('cooelf', 12),
#  ('ignc-research', 12),
#  ('rodsveiga', 12),
#  ('josedolz', 12),
#  ('tencentyouturesearch', 12),
#  ('GT-SALT', 12),
#  ('ccicconetti', 12),
#  ('wangermeng2021', 12),
#  ('twitter-research', 12),
#  ('mnikitin', 12),
#  ('zib-iol', 12),
#  ('jind11', 12),
#  ('mahmoodlab', 12),
#  ('stephenbeckr', 12),
#  ('nachiket273', 12),
#  ('neuroailab', 12),
#  ('sheffieldnlp', 12),
#  ('sebastian-hofstaetter', 12),
#  ('justld', 12),
#  ('TonghanWang', 12),
#  ('PredictiveIntelligenceLab', 12),
#  ('tsinghua-fib-lab', 12),
#  ('marius311', 12),
#  ('KurochkinAlexey', 12),
#  ('DFKI-NLP', 12),
#  ('AaltoML', 12),
#  ('rgiordan', 12),
#  ('cdluminate', 12),
#  ('cog-imperial', 12),
#  ('damo-cv', 12),
#  ('mrirecon', 12),
#  ('mt-upc', 12),
#  ('ebagdasa', 12),
#  ('nicola-decao', 12),
#  ('P2333', 12),
#  ('hli1221', 12),
#  ('VLL-HD', 12),
#  ('iancovert', 12),
#  ('BM-K', 12),
#  ('sp-uhh', 12),
#  ('suinleelab', 12),
#  ('mediabrain-sjtu', 12),
#  ('airalcorn2', 12),
#  ('coleygroup', 12),
#  ('lightaime', 12),
#  ('arobey1', 12),
#  ('befelix', 12),
#  ('mr7495', 12),
#  ('HKBU-HPML', 12),
#  ('r9y9', 12),
#  ('zhijing-jin', 12),
#  ('whai362', 12),
#  ('utahnlp', 12),
#  ('tlmakinen', 12),
#  ('castacks', 12),
#  ('klb2', 12),
#  ('mdeff', 12),
#  ('oval-group', 12),
#  ('rice-eic', 12),
#  ('araffin', 12),
#  ('msracver', 12),
#  ('qwopqwop200', 12),
#  ('BinWang28', 12),
#  ('POSTECH-CVLab', 12),
#  ('ringbdstack', 12),
#  ('toni-sm', 12),
#  ('atreyasha', 12),
#  ('HobbitLong', 12),
#  ('ahmedssabir', 12),
#  ('fajri91', 12),
#  ('tum-vision', 12),
#  ('StonyBrookNLP', 12),
#  ('ldbc', 12),
#  ('sauravmishra1710', 12),
#  ('anang0g0', 12),
#  ('wyu97', 12),
#  ('vvv214', 12),
#  ('aschethor', 12),
#  ('cosmoquester', 12),
#  ('maudzung', 12),
#  ('idstcv', 12),
#  ('VICO-UoE', 12),
#  ('ZFTurbo', 12),
#  ('LIVIAETS', 12),
#  ('uclmr', 12),
#  ('pairlab', 12),
#  ('chenhao2345', 12),
#  ('bshall', 12),
#  ('YapengTian', 12),
#  ('bcaitech1', 12),
#  ('whwu95', 12),
#  ('fundamentalvision', 12),
#  ('yingkaisha', 12),
#  ('mdda', 12),
#  ('tanner-trickle', 12),
#  ('ternaus', 12),
#  ('Agarciafernandez', 12),
#  ('hpi-xnor', 12),
#  ('CycloneBoy', 12),
#  ('ahmedelmahy', 12),
#  ('Breakend', 11),
#  ('Alibaba-NLP', 11),
#  ('ConsenSys', 11),
#  ('ZKSI', 11),
#  ('alibaba-mmai-research', 11),
#  ('AlexMoreo', 11),
#  ('KrishnaswamyLab', 11),
#  ('heatherprince', 11),
#  ('nignatiadis', 11),
#  ('datquocnguyen', 11),
#  ('THU-KEG', 11),
#  ('rezacsedu', 11),
#  ('ronghanghu', 11),
#  ('yanx27', 11),
#  ('cvlab-columbia', 11),
#  ('usccolumbia', 11),
#  ('katzfuss-group', 11),
#  ('cindyxinyiwang', 11),
#  ('MathieuCarriere', 11),
#  ('mingdachen', 11),
#  ('DetectionTeamUCAS', 11),
#  ('rezazad68', 11),
#  ('awstringer1', 11),
#  ('shmsw25', 11),
#  ('temf', 11),
#  ('usydnlp', 11),
#  ('PrincetonUniversity', 11),
#  ('danielemarinazzo', 11),
#  ('juntang-zhuang', 11),
#  ('stat-ml', 11),
#  ('Alibaba-MIIL', 11),
#  ('ictmcg', 11),
#  ('ActiveVisionLab', 11),
#  ('dslisleedh', 11),
#  ('kkoutini', 11),
#  ...]

# %%
dataByCid.ReposCreated.sum()
# Out:
# 55496
