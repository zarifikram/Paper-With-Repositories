# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import os, sys
exec(open("init_notebook.py").read())
from DataTools import DataTools
from Extractor import Extractor
from DataCleaner import DataCleaner
from RepoTools import RepoTools
# Out:
# current working dir/Volumes/Zarif/myStuff/research/repoPaper/src

# %%
# %load_ext autoreload
# %autoreload 2

# %%
mainDatasetPath = os.path.join(os.curdir, "../data/mainData.csv")
companyDf = pd.read_csv(mainDatasetPath)

# %%
DataCleaner.getDfByCidAndYear(29.0, 2022)
# Out:
#            Company                 EID   CID  \
# 322963      Github  2-s2.0-85094144803  29.0
# 322977      Github  2-s2.0-85122130821  29.0
# 322978      Github  2-s2.0-85123919166  29.0
# 322979      Github  2-s2.0-85124231358  29.0
# 322980      Github  2-s2.0-85125784747  29.0
# ...            ...                 ...   ...
# 1189029  Microsoft  2-s2.0-85112165009  29.0
# 1189030  Microsoft  2-s2.0-85111758091  29.0
# 1189031  Microsoft  2-s2.0-85109971174  29.0
# 1189032  Microsoft  2-s2.0-85096436805  29.0
# 1189033  Microsoft  2-s2.0-85095818723  29.0
#
#                                                      Title  Year  \
# 322963   Corporate hackathons, how and why? A multiple ...  2022
# 322977                                     Static analysis  2022
# 322978                           Static analysis at GitHub  2022
# 322979   Learning How to Listen: Automatically Finding ...  2022
# 322980   Human-centered approach to static-Analysis-dri...  2022
# ...

# %%
# DataCleaner.getDfByCidAndYear(137.0, 2021)
DataCleaner.companyDf
# Out:
#                Company                 EID     CID  \
# 0        23andMe, Inc.  2-s2.0-47549102444  1295.0
# 1        23andMe, Inc.  2-s2.0-49449112665  1295.0
# 2        23andMe, Inc.  2-s2.0-57249114502  1295.0
# 3        23andMe, Inc.  2-s2.0-57749179962  1295.0
# 4        23andMe, Inc.  2-s2.0-69549126536  1295.0
# ...                ...                 ...     ...
# 1199108      Microsoft  2-s2.0-84928501430    29.0
# 1199109      Microsoft  2-s2.0-84927726412    29.0
# 1199110      Microsoft  2-s2.0-84925438402    29.0
# 1199111      Microsoft  2-s2.0-84921872714    29.0
# 1199112      Microsoft  2-s2.0-84921849387    29.0
#
#                                                      Title  Year  \
# 0        The ethics of characterizing difference: Guidi...  2008
# 1        Y-chromosomal evidence of a pastoralist migrat...  2008
# 2        REJECTOR: Software for population history infe...  2008
# 3        Characterizing the time dependency of human mi...  2009
# ...

# %%
company = DataCleaner.getCompanyFromCid(29.0)
print(company)
Extractor.loadCSVFromOutput("Microsoft")
# Out:
# Github
#                                                  title  \
# 0     ICASSP 2022 Acoustic Echo Cancellation Challenge
# 1    INTERSPEECH 2021 acoustic echo cancellation ch...
# 2    ICASSP 2021 acoustic echo cancellation challen...
# 3    Crowdsourcing approach for subjective evaluati...
# 4    AIDE: Accelerating image-based ecological surv...
# ..                                                 ...
# 978                      Prioritized Experience Replay
# 979  Dueling Network Architectures for Deep Reinfor...
# 980  Asynchronous Methods for Deep Reinforcement Le...
# 981  Deep Reinforcement Learning from Self-Play in ...
# 982  LITE: Intent-based Task Representation Learnin...
#
#                                              repo_link  forks  \
# 0           https://github.com/microsoft/AEC-Challenge    111
# 1           https://github.com/microsoft/AEC-Challenge    111
# 2           https://github.com/microsoft/AEC-Challenge    111
# ...

# %%
company = 'Microsoft'
cid = DataCleaner.getCidFromCompany(company)
dfByCidAndYear = DataCleaner.getDfByCidAndYear(cid)

# %%
paperFromCompanyRepos = Extractor.loadCSVFromOutput(company)

# %%
DataCleaner.getUniqueCids(companyDf)

# %%
a = DataCleaner.getMatchedPapers(dfByCidAndYear, paperFromCompanyRepos)

# %%
a[a.Year == 2022].Year.count()
# Out:
# 51

# %%
df = DataCleaner.analyzeByCid(companyDf, 29.0, DataCleaner.getUniqueYears(companyDf))

# %%
df = DataCleaner.getInfoDfFromCidAndYear(companyDf)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 557/557 [01:02<00:00,  8.87it/s]

# %%
df["PercentMatched"] = df.MatchedPapers / df.TotalPapers * 100

# %%
papers = DataCleaner.getAllMatchingPapersInfo(companyDf)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:04<00:00, 132.78it/s]

# %%
DataTools.saveDfInCSV(papers, "matched_papers")

# %%
plt.scatter(data.TotalPapers, data.MatchedPapers)

# %%
a = Extractor.getRepoFromCompanies(['Cisco Systems'])

# %%
a[0]._requester = DataTools.getGithub().getRequester()
a[0].get_commits().totalCount
# Out:
# 20

# %%
a[400]
# Out:
# Repository(full_name="CiscoDevNet/awesome-ciscoapis")

# %%
DataCleaner.getUsernamesByCid(companyDf, 369.0)
# Out:
# ['Rohde-Schwarz']

# %%
# import time
# from requests import ConnectTimeout, ReadTimeout
# from github.GithubException import RateLimitExceededException, GithubException
# while True:
#     print("trying...")
#     try:
#         DataCleaner.getRepoInfos(companyDf)
#     except RateLimitExceededException:
#         print("rate exceeded :( Trying after 5 minutes")
#         time.sleep(300)
#     except ConnectTimeout:
#         print("internet gone :( Trying after 30 seconds")
#         time.sleep(30)
#     except ReadTimeout:
#         print("internet gone :( Trying after 30 seconds")
#         time.sleep(30)
DataCleaner.getRepoInfos(companyDf)

# %%
DataCleaner.isUnfinished(955)
# Out:
# True

# %%
RateLimitExceededException.args
# Out:
# <attribute 'args' of 'BaseException' objects>

# %%
a = DataTools.loadCSVFromOutput('705')

# %%
a.to_json('unfinished705.json')

# %%
import pickle
with open('unfinished' + str(int('955')), 'rb') as handle:
    a = pickle.load(handle)

# %%
# DataCleaner.appendRepoInfoByUsername(companyDf, 'amazon-science', 'Amazon')
DataCleaner.getCidFromCompany(companyDf, 'Amazon')
# Out:
# 1693.0

# %%
DataCleaner.getRepoInfoAllCID(companyDf)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:00<00:00, 793.42it/s]

# %%
# Out:
#        Company                 EID    CID  \
# 2740  Facebook  2-s2.0-85084305070  661.0
#
#                                                   Title  Year  \
# 2740  ClutRR: A diagnostic benchmark for inductive r...  2019
#
#                                                Abstract  \
# 2740  The recent success of natural language underst...
#
#                                              repo_link           created_at  \
# 2740  https://github.com/koustuvsinha/clutrr-baselines  2019-01-02 16:57:44
#
#                   name                      Full Name  Forks  Stars  Watchers  \
# 2740  clutrr-baselines  koustuvsinha/clutrr-baselines    3.0    8.0       8.0
#
#       Commits  Branches  Contributors  Open Issues  PullRequests  YearCreated
# 2740    123.0       1.0           1.0          1.0           0.0       2019.0

# %%
paperFromCompanyRepos = Extractor.loadCSVFromOutput(company)

# %%
cids = DataCleaner.getUniqueCids(companyDf)
companies = []
for cid in tqdm(cids):
    companies.extend(DataCleaner.getCompaniesFromCid(companyDf, cid))
allPapersCollected = Extractor.loadCSVFromOutput(companies)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:01<00:00, 323.91it/s]

# %%
b
# Out:
#                                                   title  \
# 0                   operator kogito-operator (1.6.1-ok)
# 1                                       mesh graphormer
# 2     formal specification and verification of smart...
# 3     weakly-supervised temporal action localization...
# 4     background suppression network for weakly-supe...
# ...                                                 ...
# 4118  yggdrasil decision forests: a fast and extensi...
# 4119  yggdrasil decision forests: a fast and extensi...
# 4120  lightlda: big topic models on modest computer ...
# 4121        fine-grained stochastic architecture search
# 4122  graphmaps: browsing large graphs as interactiv...
#
#                                               repo_link  forks  \
# 0     https://github.com/redhat-openshift-ecosystem/...   44.0
# 1           https://github.com/microsoft/MeshGraphormer   44.0
# 2                  https://github.com/microsoft/verisol   43.0
# ...

# %%
k = DataCleaner.getAllMatchingPapersInfo(companyDf)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.40it/s]
#
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 128.73it/s]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 28.69it/s]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 35.74it/s]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 24.80it/s]
#
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 166.83it/s]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 35.00it/s]
#
# ...

# %%
pwcAll = pd.read_json(os.path.join(os.pardir, 'data/pwcAllPapers.json'))

# %%
pwcAll.to_csv('pwcAll.csv', index=False)

# %%
k = k.drop_duplicates(['title'])

# %%
k = k.drop_duplicates(['Title'])

# %%
a= k.columns.to_list()

# %%
l = k[b]

# %%
l.to_csv('matchingPapers0.8.csv')

# %%
matchedPapersInfo = DataTools.loadCSVFromOutput('finalStuff/matched_papersV3')

# %%
matchedPapersInfo
# Out:
#           Company                 EID     CID  \
# 0     ARM Limited  2-s2.0-85117368143  1667.0
# 1     ARM Limited  2-s2.0-85123429172  1667.0
# 2       ASAPP INC  2-s2.0-85097917930   274.0
# 3       ASAPP INC  2-s2.0-85101799894   274.0
# 4       ASAPP INC  2-s2.0-85101836243   274.0
# ...           ...                 ...     ...
# 1589    Microsoft  2-s2.0-84990032654    29.0
# 1590    Microsoft  2-s2.0-84962921456    29.0
# 1591    Microsoft  2-s2.0-84990059438    29.0
# 1592    Microsoft  2-s2.0-84964588182    29.0
# 1593    Microsoft  2-s2.0-84947781852    29.0
#
#                                                   Title  Year  \
# 0           A compact model for scalable MTJ simulation  2021
# 1     A Fokker-Planck Solver to Model MTJ Stochasticity  2021
# 2     ASAPP-ASR: Multistream CNN and self-attentive ...  2020
# 3     Simple and effective few-shot named entity rec...  2020
# 4           Structured pruning of large language models  2020
# ...

# %%
# pwc
pwc = pd.read_csv(os.path.join(os.pardir, 'data/papersWithCode.csv'))
pwc['repo_url'] = pwc['repo_url'].str.lower()

# pwc paper without links 
pwcPapers = pd.read_csv(os.path.join(os.pardir, 'data/pwcAll.csv'))
# Out:
# /var/folders/6r/ybj42rmx5yzdgsy5vpnr2j980000gn/T/ipykernel_56901/102497098.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pwcPapers = pd.read_csv(os.path.join(os.pardir, 'data/pwcAll.csv'))

# %%
merged = pwcPapers.merge(pwc, how='left', left_on='title', right_on='paper_title')

# %%
merged.repo_url.isna().sum() / pwcPapers
# Out:
# 271448

# %%
merged.to_csv('pwcMerged.csv', index=False)

# %%
merged[merged.is_official==True].title.describe()
# Out:
# count                                                 82097
# unique                                                78090
# top       New Insights on Reducing Abrupt Representation...
# freq                                                     10
# Name: title, dtype: object

# %%
pwc[pwc.is_official==Tur]
# Out:
#                                               paper_url_x    arxiv_id  \
# 0       https://paperswithcode.com/paper/dynamic-netwo...  1805.10616
# 1       https://paperswithcode.com/paper/pac-bayes-bou...  1806.06827
# 2       https://paperswithcode.com/paper/automated-bri...   1806.0682
# 3       https://paperswithcode.com/paper/gradient-desc...  1802.06093
# 4       https://paperswithcode.com/paper/temporal-cohe...  1806.06811
# ...                                                   ...         ...
# 421821  https://paperswithcode.com/paper/sampling-bias...         NaN
# 421822  https://paperswithcode.com/paper/deep-fast-vis...         NaN
# 421823  https://paperswithcode.com/paper/inverse-stati...  1703.01222
# 421824  https://paperswithcode.com/paper/combining-exp...         NaN
# 421825  https://paperswithcode.com/paper/post-hoc-expl...  2305.11426
#
#                                                     title  \
# 0         Dynamic Network Model from Partial Observations
# ...
